# %% [markdown]
# Ejercicio de pandas y numpy para procesar y graficar datos

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy

df = pd.read_csv(r"C:\Users\FeJo433\Desktop\StoresData.csv")
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df["Average_Sales_Per_Customer"] = df["Store_Sales"]/df["Daily_Customer_Count"]
df.sort_values(by=['Daily_Customer_Count'], ascending=False)
dfg = df.groupby(["Store ID ", "Store_Area"]).sum().sort_values(by=['Daily_Customer_Count'], ascending=False)
display(dfg)
# Out:
#                       Items_Available  Daily_Customer_Count  Store_Sales  \
# Store ID  Store_Area
# 849       919                    1099                  1560        73810
# 350       1886                   2228                  1530        40350
# 536       1057                   1262                  1490        35420
# 95        1921                   2305                  1470        77120
# 313       1494                   1806                  1450        43640
# ...                               ...                   ...          ...
# 147       1442                   1750                   130        58920
# 231       1347                   1628                   120        72350
# 877       1259                   1493                   100        88270
# 152       1662                   1986                    70        63730
# 40        1270                   1516                    10        45480
#
#                       Average_Sales_Per_Customer
# ...

# %%
top10 = df.sort_values(by='Daily_Customer_Count', ascending=True).head(10)
top10['Store ID '] = top10['Store ID '].astype(str)
display(top10)
plt.figure(figsize=(10,8))
plt.bar(
  x=top10['Store ID '],
  height=top10['Daily_Customer_Count'],
  label="Ventas mensuales",
  color="skyblue")

plt.title("Average Daily Customer Count per Store ID")
plt.xlabel("Store ID")
plt.ylabel("Daily Customer Count")
plt.legend()
plt.show()
# Out:
#     Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales  \
# 39         40        1270             1516                    10        45480
# 151       152        1662             1986                    70        63730
# 876       877        1259             1493                   100        88270
# 230       231        1347             1628                   120        72350
# 146       147        1442             1750                   130        58920
# 887       888        1156             1398                   140        92370
# 826       827        1609             1928                   160        37920
# 710       711        1502             1815                   190        55980
# 674       675        1427             1677                   210        54590
# 1           2        1461             1752                   210        39820
#
#      Average_Sales_Per_Customer
# 39                  4548.000000
# 151                  910.428571
# ...
